# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import csv

from config import census_api_key
from pprint import pprint

# %%
# Save config information
url = 'https://api.census.gov/data/timeseries/poverty/saipe?get='
years = ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']

# Build query URL
for year in years:
    query_url = url + "NAME,SAEMHI_MOE,SAEMHI_PT&for=county:*&in=state:48&key=" + census_api_key + "&time=" + year
    response = requests.get(query_url)
    response_json = response.json()
    print(response_json)
# Out:
# [['NAME', 'SAEMHI_MOE', 'SAEMHI_PT', 'time', 'state', 'county'], ['Anderson County', '2041', '31884', '2004', '48', '001'], ['Andrews County', '2605', '40493', '2004', '48', '003'], ['Angelina County', '2274', '35749', '2004', '48', '005'], ['Aransas County', '2014', '31869', '2004', '48', '007'], ['Archer County', '2747', '43330', '2004', '48', '009'], ['Armstrong County', '2565', '40857', '2004', '48', '011'], ['Atascosa County', '2206', '34699', '2004', '48', '013'], ['Austin County', '2712', '42898', '2004', '48', '015'], ['Bailey County', '1958', '28841', '2004', '48', '017'], ['Bandera County', '2552', '40522', '2004', '48', '019'], ['Bastrop County', '2778', '44223', '2004', '48', '021'], ['Baylor County', '1745', '26873', '2004', '48', '023'], ['Bee County', '1888', '28392', '2004', '48', '025'], ['Bell County', '2557', '38253', '2004', '48', '027'], ['Bexar County', '2095', '38832', '2004', '48', '029'], ['Blanco County', '2743', '43264', '2004', '48', '031'], ['Borden Count
# ...

# %%
# Convert to data frame
census_df = pd.DataFrame(response_json)
census_df.head()
# Out:
#                  0           1          2     3      4       5
# 0             NAME  SAEMHI_MOE  SAEMHI_PT  time  state  county
# 1  Anderson County        3485      43062  2015     48     001
# 2   Andrews County        6318      72184  2015     48     003
# 3  Angelina County        3906      45428  2015     48     005
# 4   Aransas County        3353      41560  2015     48     007
