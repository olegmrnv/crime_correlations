# %%
import pandas as pd
import json
import requests
from api_keys import crime_api_key
from pprint import pprint

# %%
data = pd.read_csv("nibrs_incident_2009.csv")
data.head()
# Out:
#    agency_id  incident_id  nibrs_month_id incident_number  cargo_theft_flag  \
# 0      18798     51604181         4831419        09010663               NaN
# 1      18798     51608097         4831419        10000359               NaN
# 2      18798     51591567         4831419        09005012               NaN
# 3      18798     51580910         4831419        09000111               NaN
# 4      18798     51580911         4831419        09000113               NaN
#
#    submission_date        incident_date report_date_flag  incident_hour  \
# 0              NaN  2009-01-01 00:00:00              NaN            9.0
# 1              NaN  2009-01-12 00:00:00              NaN           19.0
# 2              NaN  2009-01-12 00:00:00              NaN            8.0
# 3              NaN  2009-01-04 00:00:00              NaN            1.0
# 4              NaN  2009-01-04 00:00:00              NaN            1.0
#
#    cleared_except_id cleared_except_date  incident_status data_home  \
# ...

# %%
data.agency_id.nunique()
# Out:
# 61

# %%
base_url = "https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key="
location = '&location=Houston+TX'

# %%
url = base_url + crime_api_key + location

# %%
respond = requests.get(url).json()
respond
# Out:
# {'latitude': 29.760803,
#  'longitude': -95.369506,
#  'location_country': 'US',
#  'precision': {'value': 4,
#   'name': 'locality',
#   'types': ['locality', 'political']},
#  'station_locator_url': 'http://www.afdc.energy.gov/afdc/locator/stations/',
#  'total_results': 79,
#  'station_counts': {'total': 260,
#   'fuels': {'BD': {'total': 1},
#    'E85': {'total': 2},
#    'ELEC': {'total': 256, 'stations': {'total': 75}},
#    'HY': {'total': 0},
#    'LNG': {'total': 0},
#    'CNG': {'total': 1},
#    'LPG': {'total': 0}}},
#  'offset': 0,
#  'fuel_stations': [{'access_code': 'public',
#    'access_days_time': 'MON: 24 hours | TUE: 24 hours | WED: 24 hours | THU: 24 hours | FRI: 24 hours | SAT: 24 hours | SUN: 24 hours',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-03-23',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 95409,
#    'open_date': None,
# ...

# %%
pprint (respond)
# Out:
# {'fuel_stations': [{'access_code': 'public',
#                     'access_days_time': 'MON: 24 hours | TUE: 24 hours | WED: '
#                                         '24 hours | THU: 24 hours | FRI: 24 '
#                                         'hours | SAT: 24 hours | SUN: 24 hours',
#                     'access_days_time_fr': None,
#                     'access_detail_code': None,
#                     'bd_blends': None,
#                     'bd_blends_fr': None,
#                     'cards_accepted': None,
#                     'city': 'Houston',
#                     'country': 'US',
#                     'date_last_confirmed': '2019-03-23',
#                     'distance': 0.05204,
#                     'distance_km': 0.08375,
#                     'e85_blender_pump': None,
#                     'ev_connector_types': ['J1772'],
#                     'ev_dc_fast_num': None,
#                     'ev_level1_evse_num': None,
#                     'ev_level2_evse_num': 1,
# ...

# %%
respond.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'location_country', 'precision', 'station_locator_url', 'total_results', 'station_counts', 'offset', 'fuel_stations'])
